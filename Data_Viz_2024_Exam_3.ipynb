# %% [markdown]
# <a href="https://colab.research.google.com/github/Jirapat2035/python_dataviz2024/blob/main/Data_Viz_2024_Exam_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Data_Docter = pd.read_csv('/content/Data_Docter_ศ.นพ.ชวลิต.csv')

# %%
Data_Docter
# Out:
#                                       name  \
# 0     ศ.นพ.ชวลิต ศูนย์มะเร็ง รพ.จุฬาลงกรณ์
# 1                           Nubeer Kithiya
# 2                          วาสนา คุ้มจิตต์
# 3                     Wansook Chompoo Ploy
# 4                              Aphit Aphit
# ...                                    ...
# 1648                           Fear Q'bick
# 1649                          Toei Nittiya
# 1650                       Ouiaii Promsuan
# 1651                      Thanyalak Banboo
# 1652                         Maii Mutchima
#
#                                                comments  ยอดไลค์  \
# 0     กดที่ลิงค์นี้เพื่อเข้าไปอ่านคอมเม้นของโพสต์ครั...      456
# 1     เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...     1400
# 2     แม่เป็นมะเร็งขั้วปอด ลามขึ้นสมองค่ะ เริ่มแรกที...      402
# 3     #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...     1600
# 4     ลูกสาวเป็นมะเร็งกระดูก Osteosarcomaช่วงเข่า อา...      480
# ...

# %% [markdown]
# ###จุดที่น่าสนใจที่ 1
# สนใจคอมเมนต์ที่มียอดไลค์มากที่สุด เพราะถ้ามียอดไลค์มาก แสดงว่าข้อมูลนั้นผู้คนสนใจและชื่นชอบมาก

# %%
Data_Docter[(Data_Docter['ยอดไลค์'] >= 500)].sort_values(by='ยอดไลค์', ascending=False)
# Out:
#                    name                                           comments  \
# 3  Wansook Chompoo Ploy  #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...
# 5            Ize Atitya  ลูกสาว 5 ขวบ เป็นมะเร็งสมองคะ ไม่มีอาการอะไร น...
# 1        Nubeer Kithiya  เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...
#
#    ยอดไลค์  จำนวนการตอบกลับ
# 3     1600               44
# 5     1500               23
# 1     1400               70

# %% [markdown]
# ####ข้อมูลที่มียอดไลค์มากที่สุด
#  คือ จำนวน 1600 ยอดไลค์ ของ Wansook Chompoo Ploy คอมเม้นว่า #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอายุ 30... ตรวจpep.ทุกปี ไม่มีอะไรผิดปกติ วันดีคืนเดือด อยู่ๆภูมิแพ้ผิวหนังขึ้นทั้งวันทั้งคืน กินยายังไงก็ไม่ลง ทั้งๆที่ก่อนหน้านั้นก็รักษาภูมิแพ้ผิวหนังจนหายแล้ว เลยนึกขึ้นได้ว่า แพทย์ผิงหนังเคยเตือนว่า หากมีอาการภูมิแพ้แบบนี้อีก ให้ตรวจอย่างอื่นที่ผิดปกติร่วมด้วย ซึ่งมันคืออาการภูมิคุ้มกันบกพร่อง(ภูมิตก)แล้วแสดงสัญญาณทางผิวหนัง .... จึงไปตรวจpep.แบบคัดเชื้อhpvร่วมด้วย เพราะเป็นคน ปจด มาไม่ปกติตั้งแต่เด็กๆ ... สรุป นางมาจริง ทั้ง 16,18 ดุสุดทั้งคู่ ณ วันที่หมออ่านผลคือ CIN ll ระยะเวลารอทำcolpo. 1เดือน ผลcolpo. ขยับไป CIN lll หมอสั่งทำ Leep ทันที เพราะระยะเดินเร็วเกินไป แต่ก็ต้องรออีก1 เดือน เนื่องด้วยว่าคุณหมอคำนวนแล้วว่า น่าจะชนกัน ปจด ซึ่งอาจทำให้แผลหายช้าลงได้

# %% [markdown]
# ####ดั้งนั้นสรุปได้ว่า
# ข้อมูลนี้มีความนิยมสูงสุดในกลุ่มผู้ชม การที่มีจำนวนไลค์มากบ่งบอกถึงการตอบรับที่ดี ความสนใจ และความพึงพอใจของผู้ใช้งานต่อเนื้อหาหรือข้อความที่โพสต์ นอกจากนี้ ยังอาจบ่งชี้ว่าเนื้อหานั้นมีคุณภาพสูง มีความเกี่ยวข้องกับความสนใจของกลุ่มเป้าหมาย หรือสามารถกระตุ้นการมีส่วนร่วมได้เป็นอย่างดี

# %% [markdown]
# ###จุดที่น่าสนใจที่ 2
# สนใจคอมเมนต์ที่มีจำนวนการตอบกลับมากที่สุด เพราะถ้ามีจำนวนการตอบกลับ แสดงให้เห็นว่าผู้ชมต้องการสอบถามหรือแลกเปลี่ยนกัน

# %%
Data_Docter[(Data_Docter['จำนวนการตอบกลับ']>=10)].sort_values(by='จำนวนการตอบกลับ', ascending=False)
# Out:
#                                    name  \
# 1                        Nubeer Kithiya
# 3                  Wansook Chompoo Ploy
# 22          รมิตา ผู้หญิงที่เป็นของขวัญ
# 46                        Neung Lertsak
# 113           Phacharatorn Subsiritavee
# 92                       Voravit Kanpai
# 10                        นู๋นิด ขนิษฐา
# 5                            Ize Atitya
# 13            Nareerat Waawaaw Singtong
# 30                       องุ่น รสสุคนธ์
# 12   อนุรักษ์ ปวีณา ประกอบนันท์ ช่างวาด
# 109                        Giw Barbegiw
# 105     Malinee Mylittleangle Thongdang
# 9                Pranutcsa Nilekhamhang
# 101                    Utchara Intalook
# 32                     ปัณฑ์ จันทร์แก้ว
# 31                          Tiw Rungsie
# 33                 Tippanan Ploy Saetan
# 133                 Chatcharin Chintham
# 135                  Niratchada Sirijan
# 2                       วาสนา คุ้มจิตต์
# 86                          Suchada Tak
# ...

# %% [markdown]
# ####ข้อมูลที่มีจำนวนการตอบกลับมากที่สุด
# คือจำนวน 70 ตอบกลับ ของ Nubeer Kithiya คอมเม้นว่า เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พฤติกรรมที่คิดว่ามีปัญหาคือ เลือกห้องน้ำที่จะอึ ถ้าไม่ใช่บ้าน หรือที่คุ้นเคย จะไม่ยอมถ่ายเลย จะอั้นไว้ ส่วนอาหารการกิน เราก็กินปกติ แบบคนทั่วไป ตามสั่ง ส้มตำ หมูทะ ชาบูบ้างตามโอกาส

# %% [markdown]
# ####ดั้งนั้นสรุปได้ว่า
#
# ข้อมูลนี้มีการตอบกลับมากที่สุดแสดงให้เห็นข้อมูลนี้กระตุ้นการสนทนาและการมีส่วนร่วมจากผู้ชมได้อย่างมาก ความถี่ในการตอบกลับที่สูงบ่งบอกถึงการที่เนื้อหานั้นทำให้ผู้ชมรู้สึกสนใจ มีความคิดเห็น หรือมีประเด็นที่ต้องการแลกเปลี่ยนกัน ซึ่งอาจเป็นเพราะเนื้อหามีความน่าสนใจ ตรงประเด็น หรือกระตุ้นให้เกิดการสนทนาอย่างกว้างขวาง
